# %%
name = list(["Д","м","и","т","р","и","й"])
sort_name = name.copy()
sort_name.sort()
union_list = name[3:] + sort_name
print(name, sort_name, union_list, sep='\n')
# Out:
# ['Д', 'м', 'и', 'т', 'р', 'и', 'й']
# ['Д', 'и', 'и', 'й', 'м', 'р', 'т']
# ['т', 'р', 'и', 'й', 'Д', 'и', 'и', 'й', 'м', 'р', 'т']
